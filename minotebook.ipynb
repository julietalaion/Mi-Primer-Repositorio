# %%
print('hola juli')
# Out:
# hola juli

# %%
import pandas as pd
import numpy as np

# %%
df_crudo = pd.read_csv('data/credit_scores.csv' , sep=';')

# %%
df = df_crudo.drop('xml_response', axis=1)

# %%
# Me trae las primeras filas
df.head(2)
# Out:
#         id  score                     name sex  user_id  \
# 0  3678359    120  SANTILLAN FACUNDO ARIEL   M  4053914
# 1  3678358    710    VALLBONA DAIANA LAURA   F  4053904
#
#                 created_at               updated_at  accepted modelo_score  \
# 0  2025-09-04 02:11:07.953  2025-09-04 02:11:07.973      True            H
# 1  2025-09-04 02:11:02.084  2025-09-04 02:11:02.111      True            H
#
#                                            domicilio  ...  last_name  \
# 0                GABOTO 1014 MERLO 1722 BUENOS AIRES  ...  SANTILLAN
# 1  ALCORTA 3653 MATANZA BUENOS AIRES TINOGASTA 17...  ...   VALLBONA
#
#            cuil    work_type third_party_committed_amount  \
# 0  2.044353e+10  Desempleado                          0.0
# 1  2.737989e+10  Desempleado                       1437.5
#
#   third_party_total_loans_amount post_code  lock_version sueldo_bruto  \
# 0                              0    1722.0             1       692000
# ...

# %%
# para traerme las ultimas filas
df.tail()
# Out:
#           id  score                             name sex  user_id  \
# 995  3677321      2            ACOSTA SARA ELIZABETH   F  4052684
# 996  3677320      5               SILVA DEBORA BELEN   F  4052681
# 997  3677319    120  VILLEGAS PACHECO GONZALO LEONEL   M  4052680
# 998  3677318    670       RODRIGUEZ ROCIO MARIANELLA   F  4052676
# 999  3677317    461         CHIAPPERO MARIA VICTORIA   F  4052678
#
#                   created_at               updated_at  accepted modelo_score  \
# 995  2025-09-03 23:34:59.254  2025-09-03 23:34:59.305      True            H
# 996  2025-09-03 23:34:51.627  2025-09-03 23:34:51.659      True            H
# 997  2025-09-03 23:34:44.141  2025-09-03 23:34:44.163      True            H
# 998  2025-09-03 23:34:39.908  2025-09-03 23:34:39.920      True            H
# 999  2025-09-03 23:34:31.822  2025-09-03 23:34:31.880      True            H
#
#                                              domicilio  ...  last_name  \
# ...

# %%
#para traerme filas al azar
df.sample(5)
# Out:
#           id  score                                name sex  user_id  \
# 302  3678046     17  SANDOVAL ROJAS ELIZABETH FRANCISCA   F  4053535
# 412  3677932    782           VILLALBA MILENA ARGENTINA   F  4053400
# 199  3678154     25                  ADARO JOSE RICHARD   M  4053651
# 624  3677708      8               GUERRA ROBERTO FABIAN   M  4053124
# 893  3677425    141               AVILA BOLTES CRISTELA   F  4052808
#
#                   created_at               updated_at  accepted modelo_score  \
# 302  2025-09-04 01:21:11.741  2025-09-04 01:21:11.768      True            H
# 412  2025-09-04 01:04:03.736  2025-09-04 01:04:03.772      True            H
# 199  2025-09-04 01:37:33.187  2025-09-04 01:37:33.215      True            H
# 624  2025-09-04 00:29:35.255  2025-09-04 00:29:35.305      True            H
# 893  2025-09-03 23:52:20.114  2025-09-03 23:52:20.141      True            H
#
#                                              domicilio  ...     last_name  \
# ...

# %%
#Para decirme cuantas filas y columnas tiene mi dataframe
df.shape
# Out:
# (1000, 38)

# %%
df.describe()
# Out:
#                  id        score       user_id  empleadores  bcra_cheques  \
# count  1.000000e+03  1000.000000  1.000000e+03          0.0   1000.000000
# mean   3.677838e+06   459.911000  4.051129e+06          NaN      0.004000
# std    3.028732e+02   339.552899  2.891160e+04          NaN      0.126491
# min    3.677317e+06     1.000000  3.522182e+06          NaN      0.000000
# 25%    3.677574e+06    96.000000  4.052961e+06          NaN      0.000000
# 50%    3.677842e+06   532.500000  4.053268e+06          NaN      0.000000
# 75%    3.678100e+06   778.000000  4.053588e+06          NaN      0.000000
# max    3.678359e+06   996.000000  4.053914e+06          NaN      4.000000
#
#        fraudes  creditos_vigentes  creditos_cancelados    ses_level  \
# count      0.0                0.0                  0.0  1000.000000
# mean       NaN                NaN                  NaN     8.295000
# std        NaN                NaN                  NaN     1.881892
# ...

# %%
df.dtypes
# Out:
# id                                  int64
# score                               int64
# name                               object
# sex                                object
# user_id                             int64
# created_at                         object
# updated_at                         object
# accepted                             bool
# modelo_score                       object
# domicilio                          object
# telefonos                          object
# familiares                         object
# empleadores                       float64
# laborales                          object
# morosidades                        object
# morosidades_historicas             object
# bcra_cheques                        int64
# modelos_ses                        object
# fraudes                           float64
# creditos_vigentes                 float64
# creditos_cancelados               float64
# ses_level                           int64
# ...

# %%
scores = df['score']

# %%
scores.describe()
# Out:
# count    1000.000000
# mean      459.911000
# std       339.552899
# min         1.000000
# 25%        96.000000
# 50%       532.500000
# 75%       778.000000
# max       996.000000
# Name: score, dtype: float64
